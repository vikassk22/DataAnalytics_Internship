# %%
import pandas as pd
df = pd.read_csv("../data/TMDB_movie_dataset.csv", encoding="ISO-8859-1")
print(f"Dataset has {df.shape[0]} rows and {df.shape[1]} columns.")
df.head(5)
# Out:
# Dataset has 1048575 rows and 24 columns.
#        id            title  vote_average  vote_count    status release_date  \
# 0   27205        Inception         8.364       34495  Released   15-07-2010
# 1  157336     Interstellar         8.417       32571  Released   05-11-2014
# 2     155  The Dark Knight         8.512       30619  Released   16-07-2008
# 3   19995           Avatar         7.573       29815  Released   15-12-2009
# 4   24428     The Avengers         7.710       29166  Released   25-04-2012
#
#       revenue  runtime  adult                     backdrop_path  ...  \
# 0   825532764      148  False  /8ZTVqvKDQ8emSGUEMjsS4yHAwrp.jpg  ...
# 1   701729206      169  False  /pbrkL804c8yAv3zBZR4QPEafpAR.jpg  ...
# 2  1004558444      152  False  /nMKdUUepR0i5zn0y1T4CsSB5chy.jpg  ...
# 3  2923706026      162  False  /vL5LR6WdxWPjLPFRLe133jXWsh5.jpg  ...
# 4  1518815515      143  False  /9BBTo63ANSmhC4e6r62OJFuK2GL.jpg  ...
#
#     original_title                                           overview  \
# 0        Inception  Cobb, a skilled thief who commits corporate es...
# 1     Interstellar  The adventures of a group of explorers who mak...
# 2  The Dark Knight  Batman raises the stakes in his war on crime. ...
# 3           Avatar  In the 22nd century, a paraplegic Marine is di...
# 4     The Avengers  When an unexpected enemy emerges and threatens...
#
#   popularity                       poster_path  \
# 0     83.952  /oYuLEt3zVCKq57qu2F8dT7NIa6f.jpg
# 1    140.241  /gEU2QniE6E77NI6lCU6MxlNBvIx.jpg
# 2    130.643  /qJ2tW6WMUDux911r6m7haRef0WH.jpg
# 3     79.932  /kyeqWdyUXW608qlYkRqosgbbJyK.jpg
# 4     98.082   /RYMX2wcKCBAr24UyPD7xwmjaTn.jpg
#
#                                              tagline  \
# 0               Your mind is the scene of the crime.
# 1  Mankind was born on Earth. It was never meant ...
# 2                  Welcome to a world without rules.
# 3                        Enter the world of Pandora.
# 4                            Some assembly required.
#
#                                         genres  \
# 0           Action, Science Fiction, Adventure
# 1            Adventure, Drama, Science Fiction
# 2               Drama, Action, Crime, Thriller
# 3  Action, Adventure, Fantasy, Science Fiction
# 4           Science Fiction, Action, Adventure
#
#                                 production_companies  \
# 0  Legendary Pictures, Syncopy, Warner Bros. Pict...
# 1  Legendary Pictures, Syncopy, Lynda Obst Produc...
# 2  DC Comics, Legendary Pictures, Syncopy, Isobel...
# 3  Dune Entertainment, Lightstorm Entertainment, ...
# 4                                     Marvel Studios
#
#                        production_countries  \
# 0  United Kingdom, United States of America
# 1  United Kingdom, United States of America
# 2  United Kingdom, United States of America
# 3  United States of America, United Kingdom
# 4                  United States of America
#
#                      spoken_languages  \
# 0  English, French, Japanese, Swahili
# 1                             English
# 2                   English, Mandarin
# 3                    English, Spanish
# 4             English, Hindi, Russian
#
#                                             keywords
# 0  rescue, mission, dream, airplane, paris, franc...
# 1  rescue, future, spacecraft, race against time,...
# 2  joker, sadism, chaos, secret identity, crime f...
# 3  future, society, culture clash, space travel, ...
# 4  new york city, superhero, shield, based on com...
#
# [5 rows x 24 columns]

# %%
print(df.columns.tolist())
print(df.dtypes)
# Out:
# ['id', 'title', 'vote_average', 'vote_count', 'status', 'release_date', 'revenue', 'runtime', 'adult', 'backdrop_path', 'budget', 'homepage', 'imdb_id', 'original_language', 'original_title', 'overview', 'popularity', 'poster_path', 'tagline', 'genres', 'production_companies', 'production_countries', 'spoken_languages', 'keywords']
# id                        int64
# title                    object
# vote_average            float64
# vote_count                int64
# status                   object
# release_date             object
# revenue                   int64
# runtime                   int64
# adult                      bool
# backdrop_path            object
# budget                    int64
# homepage                 object
# imdb_id                  object
# original_language        object
# original_title           object
# overview                 object
# popularity              float64
# poster_path              object
# tagline                  object
# genres                   object
# production_companies     object
# production_countries     object
# spoken_languages         object
# keywords                 object
# dtype: object

# %%
print("\nMissing values:\n", df.isnull().sum())
df.describe(include="all").T.head(20)
# Out:
# Missing values:
#  id                           0
# title                        9
# vote_average                 0
# vote_count                   0
# status                       0
# release_date            216568
# revenue                      0
# runtime                      0
# adult                        0
# backdrop_path           756556
# budget                       0
# homepage                936753
# imdb_id                 507558
# original_language            0
# original_title               9
# overview                224810
# popularity                   0
# poster_path             351930
# tagline                 891035
# genres                  435316
# production_companies    578840
# production_countries    481412
# spoken_languages        456155
# keywords                758781
# dtype: int64
#                        count  unique                               top  \
# id                 1048575.0     NaN                               NaN
# title                1048566  900830                              Home
# vote_average       1048575.0     NaN                               NaN
# vote_count         1048575.0     NaN                               NaN
# status               1048575       6                          Released
# release_date          832007   42295                        01-01-2006
# revenue            1048575.0     NaN                               NaN
# runtime            1048575.0     NaN                               NaN
# adult                1048575       2                             False
# backdrop_path         292019  289427  /3CxwYgqGtJ6UEGfWUT0gMYCIlFP.jpg
# budget             1048575.0     NaN                               NaN
# homepage              111822  105038     https://vimeo.com/user3392640
# imdb_id               541017  538830                        tt32094375
# original_language    1048575     176                                en
# original_title       1048566  924395                          ????????
# overview              823765  797532
# popularity         1048575.0     NaN                               NaN
# poster_path           696645  692667  /sRs2R6qI9C3Liv3hWrQTdmoSqqp.jpg
# tagline               157540  151381                           English
# genres                613259   13431                       Documentary
#
#                       freq           mean              std   min       25%  \
# id                     NaN  820631.492759    468164.881715   2.0  420719.5
# title                  140            NaN              NaN   NaN       NaN
# vote_average           NaN       2.070838         3.120089   0.0       0.0
# vote_count             NaN      20.459518        331.56666   0.0       0.0
# status             1015468            NaN              NaN   NaN       NaN
# release_date          2901            NaN              NaN   NaN       NaN
# revenue                NaN  790323.104378  20596632.218036 -12.0       0.0
# runtime                NaN      47.380917        62.699866 -28.0       0.0
# adult               950804            NaN              NaN   NaN       NaN
# backdrop_path          157            NaN              NaN   NaN       NaN
# budget                 NaN  301576.380263   5615899.740098   0.0       0.0
# homepage                65            NaN              NaN   NaN       NaN
# imdb_id                 98            NaN              NaN   NaN       NaN
# original_language   573581            NaN              NaN   NaN       NaN
# original_title         190            NaN              NaN   NaN       NaN
# overview              1218            NaN              NaN   NaN       NaN
# popularity             NaN       1.212535         7.839576   0.0       0.6
# poster_path             54            NaN              NaN   NaN       NaN
# tagline                270            NaN              NaN   NaN       NaN
# genres              115883            NaN              NaN   NaN       NaN
#
#                         50%        75%           max
# id                 728751.0  1263762.5     1532449.0
# title                   NaN        NaN           NaN
# vote_average            0.0        5.0          10.0
# vote_count              0.0        1.0       34495.0
# status                  NaN        NaN           NaN
# release_date            NaN        NaN           NaN
# revenue                 0.0        0.0  4999999999.0
# runtime                21.0       89.0       14400.0
# adult                   NaN        NaN           NaN
# backdrop_path           NaN        NaN           NaN
# budget                  0.0        0.0   999999999.0
# homepage                NaN        NaN           NaN
# imdb_id                 NaN        NaN           NaN
# original_language       NaN        NaN           NaN
# original_title          NaN        NaN           NaN
# overview                NaN        NaN           NaN
# popularity              0.6      0.901      2994.357
# poster_path             NaN        NaN           NaN
# tagline                 NaN        NaN           NaN
# genres                  NaN        NaN           NaN

# %%
print("\nDuplicate values:\n", df.duplicated().sum())
df.describe(include="all").T.head(20)
# Out:
# Duplicate values:
#  375
#                        count  unique                               top  \
# id                 1048575.0     NaN                               NaN
# title                1048566  900830                              Home
# vote_average       1048575.0     NaN                               NaN
# vote_count         1048575.0     NaN                               NaN
# status               1048575       6                          Released
# release_date          832007   42295                        01-01-2006
# revenue            1048575.0     NaN                               NaN
# runtime            1048575.0     NaN                               NaN
# adult                1048575       2                             False
# backdrop_path         292019  289427  /3CxwYgqGtJ6UEGfWUT0gMYCIlFP.jpg
# budget             1048575.0     NaN                               NaN
# homepage              111822  105038     https://vimeo.com/user3392640
# imdb_id               541017  538830                        tt32094375
# original_language    1048575     176                                en
# original_title       1048566  924395                          ????????
# overview              823765  797532
# popularity         1048575.0     NaN                               NaN
# poster_path           696645  692667  /sRs2R6qI9C3Liv3hWrQTdmoSqqp.jpg
# tagline               157540  151381                           English
# genres                613259   13431                       Documentary
#
#                       freq           mean              std   min       25%  \
# id                     NaN  820631.492759    468164.881715   2.0  420719.5
# title                  140            NaN              NaN   NaN       NaN
# vote_average           NaN       2.070838         3.120089   0.0       0.0
# vote_count             NaN      20.459518        331.56666   0.0       0.0
# status             1015468            NaN              NaN   NaN       NaN
# release_date          2901            NaN              NaN   NaN       NaN
# revenue                NaN  790323.104378  20596632.218036 -12.0       0.0
# runtime                NaN      47.380917        62.699866 -28.0       0.0
# adult               950804            NaN              NaN   NaN       NaN
# backdrop_path          157            NaN              NaN   NaN       NaN
# budget                 NaN  301576.380263   5615899.740098   0.0       0.0
# homepage                65            NaN              NaN   NaN       NaN
# imdb_id                 98            NaN              NaN   NaN       NaN
# original_language   573581            NaN              NaN   NaN       NaN
# original_title         190            NaN              NaN   NaN       NaN
# overview              1218            NaN              NaN   NaN       NaN
# popularity             NaN       1.212535         7.839576   0.0       0.6
# poster_path             54            NaN              NaN   NaN       NaN
# tagline                270            NaN              NaN   NaN       NaN
# genres              115883            NaN              NaN   NaN       NaN
#
#                         50%        75%           max
# id                 728751.0  1263762.5     1532449.0
# title                   NaN        NaN           NaN
# vote_average            0.0        5.0          10.0
# vote_count              0.0        1.0       34495.0
# status                  NaN        NaN           NaN
# release_date            NaN        NaN           NaN
# revenue                 0.0        0.0  4999999999.0
# runtime                21.0       89.0       14400.0
# adult                   NaN        NaN           NaN
# backdrop_path           NaN        NaN           NaN
# budget                  0.0        0.0   999999999.0
# homepage                NaN        NaN           NaN
# imdb_id                 NaN        NaN           NaN
# original_language       NaN        NaN           NaN
# original_title          NaN        NaN           NaN
# overview                NaN        NaN           NaN
# popularity              0.6      0.901      2994.357
# poster_path             NaN        NaN           NaN
# tagline                 NaN        NaN           NaN
# genres                  NaN        NaN           NaN

# %%
print(f"Filtered out movies released before 2000")
df['release_date'] = pd.to_datetime(df['release_date'], errors='coerce', dayfirst=True)
df['release_year'] = df['release_date'].dt.year
filtered_df = df[df['release_year'] >= 2000]
print(f"We have {filtered_df.shape[0]} movies released in or after 2000.")
# Out:
# Filtered out movies released before 2000
# We have 563819 movies released in or after 2000.
